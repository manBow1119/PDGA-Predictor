# %% [markdown]
# ## Making a Web Scraper

# %%
# import dependencies
import time
from selenium import webdriver
from datetime import datetime

# %% [markdown]
# ## Opening the website

# %%
# path of the chromedriver
chrome_driver = webdriver.Chrome('/Users/bowbrannon3/Documents/Data_Science/chromedriver')
# Out:
# /var/folders/0y/p5wv0k811bxbr5bsf_fjdm3w0000gn/T/ipykernel_80305/158780501.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome_driver = webdriver.Chrome('/Users/bowbrannon3/Documents/Data_Science/chromedriver')

# %%
# url of website to be scraped - event number for "Champions Cup"
url = "https://www.pdga.com/tour/event/55580"

# to open the url in browser
chrome_driver.get(url)

# %% [markdown]
# ## Navigate to Event and collect round ratings for top 25 players

# %%
# navigate to scores table, and click 'show round ratings'
ratings = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[123]/a[1]'

# get that article
link = chrome_driver.find_element("xpath", ratings)
#click to open
link.click()

# read the text of article
print(link.text)
# Out:
# Hide round ratings

# %%
# Get place, player name, and round ratings
#place, to add to player array
current_place = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[1]'
#last tr increments
second = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[2]/td[1]' 

place = chrome_driver.find_element('xpath', current_place).text
print(place)

player = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[3]/a'
#same for player name
second_player = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[2]/td[3]/a'

name = chrome_driver.find_element('xpath', player).text
print(name)

#find first two round ratings to determine - starts at 8, skips by two
rd1_rating = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[8]'
rd2_rating = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[10]'

rating = chrome_driver.find_element('xpath', rd1_rating).text
rating2 = chrome_driver.find_element('xpath', rd2_rating).text

print(rating)
print(rating2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       4 #last tr increments
#       5 second = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[2]/td[1]'
# ----> 7 place = chrome_driver.find_element('xpath', current_place).text
#       8 print(place)
#      10 player = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[3]/a'
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     854     by = By.CSS_SELECTOR
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[1]/td[1]"}
#   (Session info: chrome=104.0.5112.101)
# Stacktrace:
# 0   chromedriver                        0x000000010078dd60 chromedriver + 3792224
# 1   chromedriver                        0x0000000100724874 chromedriver + 3360884
# 2   chromedriver                        0x0000000100425184 chromedriver + 217476
# 3   chromedriver                        0x0000000100454f5c chromedriver + 413532
# 4   chromedriver                        0x000000010047db2c chromedriver + 580396
# 5   chromedriver                        0x000000010044a3e4 chromedriver + 369636
# 6   chromedriver                        0x0000000100763234 chromedriver + 3617332
# 7   chromedriver                        0x00000001007676c4 chromedriver + 3634884
# 8   chromedriver                        0x000000010076bcb8 chromedriver + 3652792
# 9   chromedriver                        0x000000010076815c chromedriver + 3637596
# 10  chromedriver                        0x00000001007467f8 chromedriver + 3500024
# 11  chromedriver                        0x000000010077fc3c chromedriver + 3734588
# 12  chromedriver                        0x000000010077fda0 chromedriver + 3734944
# 13  chromedriver                        0x00000001007945a4 chromedriver + 3818916
# 14  libsystem_pthread.dylib             0x00000001c545026c _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001c544b08c thread_start + 8

# %% [markdown]
# ## Iterating through top 25

# %%
import numpy as np
# create arrays to store info for dataframes
places = np.arange(1,26)
names = []
rd1_ratings = []
rd2_ratings = []
rd3_ratings = []
rd4_ratings = []
payouts = []

# %%
# get info from top 25 players and add to arrays
place = 1
for x in range (1,26):
    #print(f'Place {place}:') 
    #place +=1
    name_path = f'/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[124]/table[2]/tbody/tr[{x}]/td[3]/a'
    title = chrome_driver.find_element('xpath',name_path)
    #add to names array
    names.append(title.text)
    
    # iterating through round ratings
    for y in range(8,16,2):
        rd_path = f'/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[124]/table[2]/tbody/tr[{x}]/td[{y}]'
        score = chrome_driver.find_element('xpath', rd_path).text
        
        if (y/2-3==1):
            rd1_ratings.append(score)
        elif (y/2-3==2):
            rd2_ratings.append(score)
        elif (y/2-3==3):
            rd3_ratings.append(score)
        else:
            rd4_ratings.append(score)
        
        print(f'{x} Scores:')
        print(score)
    pay_path = f'/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[124]/table[2]/tbody/tr[{x}]/td[16]'
    cash = chrome_driver.find_element('xpath',pay_path).text
    payouts.append(cash)
# Out:
# 1 Scores:
# 1016
# 1 Scores:
# 1091
# 1 Scores:
# 1048
# 1 Scores:
# 1091
# 2 Scores:
# 1062
# 2 Scores:
# 1059
# 2 Scores:
# 1064
# 2 Scores:
# 1067
# 3 Scores:
# 1053
# 3 Scores:
# 1067
# 3 Scores:
# 1016
# 3 Scores:
# 1091
# 4 Scores:
# 1053
# 4 Scores:
# 1043
# 4 Scores:
# 1032
# 4 Scores:
# 1091
# 5 Scores:
# 1025
# 5 Scores:
# 1051
# 5 Scores:
# 1048
# 5 Scores:
# 1091
# 6 Scores:
# 1034
# 6 Scores:
# 1043
# 6 Scores:
# 1072
# 6 Scores:
# 1059
# 7 Scores:
# 1043
# 7 Scores:
# 1027
# 7 Scores:
# 1072
# 7 Scores:
# 1051
# 8 Scores:
# 1053
# 8 Scores:
# 1019
# 8 Scores:
# 1040
# 8 Scores:
# 1083
# 9 Scores:
# 1053
# 9 Scores:
# 1035
# 9 Scores:
# 1064
# 9 Scores:
# 1043
# 10 Scores:
# 1016
# 10 Scores:
# 1051
# 10 Scores:
# 1048
# 10 Scores:
# 1067
# 11 Scores:
# 1006
# 11 Scores:
# 1051
# 11 Scores:
# 1032
# 11 Scores:
# 1091
# 12 Scores:
# 1071
# 12 Scores:
# 1035
# 12 Scores:
# 1016
# 12 Scores:
# 1059
# 13 Scores:
# 1025
# 13 Scores:
# 1035
# 13 Scores:
# 1048
# 13 Scores:
# 1067
# 14 Scores:
# 1025
# 14 Scores:
# 1043
# 14 Scores:
# 1032
# 14 Scores:
# 1075
# 15 Scores:
# 1006
# 15 Scores:
# 1051
# 15 Scores:
# 1056
# 15 Scores:
# 1059
# 16 Scores:
# 1043
# 16 Scores:
# 1027
# 16 Scores:
# 1064
# 16 Scores:
# 1035
# 17 Scores:
# 1025
# 17 Scores:
# 1067
# 17 Scores:
# 1016
# 17 Scores:
# 1051
# 18 Scores:
# 1034
# 18 Scores:
# 1035
# 18 Scores:
# 1040
# 18 Scores:
# 1051
# 19 Scores:
# 997
# 19 Scores:
# 1075
# 19 Scores:
# 1024
# 19 Scores:
# 1059
# 20 Scores:
# 1053
# 20 Scores:
# 1027
# 20 Scores:
# 1032
# 20 Scores:
# 1051
# 21 Scores:
# 1062
# 21 Scores:
# 1035
# 21 Scores:
# 1064
# 21 Scores:
# 995
# 22 Scores:
# 1043
# 22 Scores:
# 1067
# 22 Scores:
# 1040
# 22 Scores:
# 1003
# 23 Scores:
# 1034
# 23 Scores:
# 1019
# 23 Scores:
# 1032
# 23 Scores:
# 1059
# 24 Scores:
# 988
# 24 Scores:
# 1043
# 24 Scores:
# 1040
# 24 Scores:
# 1059
# 25 Scores:
# 1034
# 25 Scores:
# 1019
# 25 Scores:
# 1048
# 25 Scores:
# 1035

# %%
# for y in range(8,16,2):
#     rd_path = f'/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[106]/table[2]/tbody/tr[{x}]/td[{y}]'
#     score = chrome_driver.find_element('xpath', rd_path)
#     print(score.text)

# %%
#testing 
for payout in payouts:
    print(payout)
# Out:
# $6,000
# $3,500
# $2,700
# $1,950
# $1,950
# $1,600
# $1,400
# $1,400
# $1,400
# $1,150
# $1,150
# $925
# $925
# $925
# $925
# $820
# $745
# $745
# $745
# $745
# $665
# $665
# $635
# $605
# $605

# %%
## Create Dataframe from arrays
import pandas as pd

LVC_22 = pd.DataFrame({"Place":places, "Name": names, "Round_1":rd1_ratings, "Round_2": rd2_ratings, "Round_3": rd3_ratings, "Round_4": rd4_ratings, "Payout": payouts})
LVC_22.head(20)
# Out:
#     Place               Name Round_1 Round_2 Round_3 Round_4  Payout
# 0       1        Drew Gibson    1016    1091    1048    1091  $6,000
# 1       2        Gannon Buhr    1062    1059    1064    1067  $3,500
# 2       3    Calvin Heimburg    1053    1067    1016    1091  $2,700
# 3       4        Kevin Jones    1053    1043    1032    1091  $1,950
# 4       5     Luke Humphries    1025    1051    1048    1091  $1,950
# 5       6     Tristan Tanner    1034    1043    1072    1059  $1,600
# 6       7      Scott Withers    1043    1027    1072    1051  $1,400
# 7       8        Adam Hammes    1053    1019    1040    1083  $1,400
# 8       9    Richard Wysocki    1053    1035    1064    1043  $1,400
# 9      10        Luke Samson    1016    1051    1048    1067  $1,150
# 10     11     Thomas Gilbert    1006    1051    1032    1091  $1,150
# 11     12    Chris Dickerson    1071    1035    1016    1059    $925
# 12     13  Colten Montgomery    1025    1035    1048    1067    $925
# 13     14     Nikko Locastro    1025    1043    1032    1075    $925
# 14     15      Ezra Aderhold    1006    1051    1056    1059    $925
# 15     16    Garrett Gurthie    1043    1027    1064    1035    $820
# 16     17     Linus Carlsson    1025    1067    1016    1051    $745
# 17     18       Chandler Fry    1034    1035    1040    1051    $745
# 18     19      Noah Meintsma     997    1075    1024    1059    $745
# 19     20      Chris Pinegar    1053    1027    1032    1051    $745

# %%
#setting index to place
LVC_22.set_index('Place', inplace = True)
#Adding tournament column
LVC_22['Tournament'] = 'LVC'
LVC_22 = LVC_22[['Tournament', 'Name', 'Round_1', 'Round_2','Round_3', 'Round_4', 'Payout']]
LVC_22.head()
# Out:
#       Tournament             Name Round_1 Round_2 Round_3 Round_4  Payout
# Place
# 1            LVC      Drew Gibson    1016    1091    1048    1091  $6,000
# 2            LVC      Gannon Buhr    1062    1059    1064    1067  $3,500
# 3            LVC  Calvin Heimburg    1053    1067    1016    1091  $2,700
# 4            LVC      Kevin Jones    1053    1043    1032    1091  $1,950
# 5            LVC   Luke Humphries    1025    1051    1048    1091  $1,950

# %%
LVC_22.to_csv("../Tournament_CSVs/LVC_22.csv")

# %%
# # See if other events/years are same
# # url of website to be scraped - event number for "European Open"
# url = "https://www.pdga.com/tour/event/58201"

# # to open the url in browser
# chrome_driver.get(url)

# # navigate to scores table, and click 'show round ratings'
# ratings = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[97]/a[1]'
# # ratings link did not work this time

# # from selenium.webdriver.common.by import By
# # # get that article
# link = chrome_driver.find_element('xpath',ratings)

# # click to open
# link.click()

# # read the text of article
# print(link.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [16], in <cell line: 6>()
#       3 url = "https://www.pdga.com/tour/event/58201"
#       5 # to open the url in browser
# ----> 6 chrome_driver.get(url)
#       8 # navigate to scores table, and click 'show round ratings'
#       9 ratings = '/html/body/div[4]/section/div/div/div/div/div/div/div/div/div/div/div[11]/div/div[2]/details[1]/div[97]/a[1]'
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:447, in WebDriver.get(self, url)
#     443 def get(self, url: str) -> None:
#     444     """
#     445     Loads a web page in the current browser session.
#     446     """
# --> 447     self.execute(Command.GET, {'url': url})
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~/opt/miniconda3/envs/datacamp/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=104.0.5112.79)
# Stacktrace:
# 0   chromedriver                        0x00000001006fdd60 chromedriver + 3792224
# 1   chromedriver                        0x0000000100694874 chromedriver + 3360884
# 2   chromedriver                        0x0000000100395184 chromedriver + 217476
# 3   chromedriver                        0x000000010038709c chromedriver + 159900
# 4   chromedriver                        0x00000001003815e8 chromedriver + 136680
# 5   chromedriver                        0x00000001003ed348 chromedriver + 578376
# 6   chromedriver                        0x00000001003ba3e4 chromedriver + 369636
# 7   chromedriver                        0x00000001006d3234 chromedriver + 3617332
# 8   chromedriver                        0x00000001006d76c4 chromedriver + 3634884
# 9   chromedriver                        0x00000001006dbcb8 chromedriver + 3652792
# 10  chromedriver                        0x00000001006d815c chromedriver + 3637596
# 11  chromedriver                        0x00000001006b67f8 chromedriver + 3500024
# 12  chromedriver                        0x00000001006efc3c chromedriver + 3734588
# 13  chromedriver                        0x00000001006efda0 chromedriver + 3734944
# 14  chromedriver                        0x00000001007045a4 chromedriver + 3818916
# 15  libsystem_pthread.dylib             0x00000001c545026c _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001c544b08c thread_start + 8
